# %% [markdown]
# # Anime Character Generation Using Generative Learning

# %% [markdown]
# Author: Shreenidhi L Nayak
# Registration number: 200968006
# DL Lab Batch 1

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# This project will be implementing Generative Adversarial Networks (GANs) first published in the original GAN paper by Goodfellow et al. in 2014.
# For the implementations in this project, Tensorflow library developed by Google will be used.

# %%
import tensorflow as tf
from google.colab import drive

# %% [markdown]
# ## Import the images

# %% [markdown]
# The image dataset is taken from kaggle.
# Link: https://www.kaggle.com/datasets/soumikrakshit/anime-faces
#
# This dataset was generated by scrapping images from www.getchu.com
# All images consist of only the facial image of the anime characters
#
# ### Metadata:
# The images are of png format
# There are a total of 21551 images
# The images are sized 64x64 pixels and are coloured rgb images

# %%
# we will import the dataset from the google drive by first mounting it

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set the path of the images directory to a variable

data_dir = '/content/drive/MyDrive/Dataset/Anime Faces'

# %%
# use the image_dataset_from_directory function from keras utils. 
# the images are loaded in batches of size 32
# The data gets stored as tensors meaning there is no need for any datatype convertion

anime_faces = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    labels=None,
    label_mode=None,
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(64, 64),
    shuffle=False
)
